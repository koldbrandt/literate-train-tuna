# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_res_trans = pd.read_csv('../trainstats/Resnet50-transfer.csv', index_col=0)
df_res = pd.read_csv('../trainstats/Resnet50-no-transfer.csv', index_col=0)

# %%
df_res_trans
# Out:
#     train_acc  test_acc  train_loss  test_loss
# 0    0.744504  0.849624    0.568674   0.393538
# 1    0.893991  0.893126    0.303685   0.233686
# 2    0.933073  0.932868    0.184469   0.164205
# 3    0.954568  0.940387    0.130429   0.141414
# 4    0.968735  0.947905    0.097269   0.126489
# 5    0.980948  0.948980    0.072114   0.117469
# 6    0.983879  0.953813    0.057753   0.110623
# 7    0.985833  0.954887    0.048276   0.110076
# 8    0.990230  0.955961    0.035513   0.112791
# 9    0.996092  0.957573    0.027316   0.105240
# 10   0.998046  0.956498    0.019516   0.113187
# 11   0.996092  0.955961    0.018497   0.111258
# 12   0.999511  0.955424    0.012678   0.111671

# %%
df_res
# Out:
#     train_acc  test_acc  train_loss  test_loss
# 0    0.538837  0.480129    0.695414   0.724168
# 1    0.536395  0.545113    0.699947   0.685317
# 2    0.557401  0.562299    0.687094   0.680511
# 3    0.561798  0.578410    0.683227   0.671934
# 4    0.618466  0.619227    0.660933   0.655779
# 5    0.605765  0.540279    0.668532   0.730084
# 6    0.627748  0.616541    0.649552   0.651198
# 7    0.651685  0.635338    0.633804   0.642018
# 8    0.649731  0.640709    0.628340   0.652992
# 9    0.644358  0.626745    0.651517   0.651644
# 10   0.672203  0.650913    0.607276   0.633992
# 11   0.695652  0.662728    0.590874   0.616914
# 12   0.700537  0.675618    0.585378   0.599558
# 13   0.702980  0.665951    0.572780   0.624346
# 14   0.711285  0.685822    0.565219   0.612492
# 15   0.726429  0.693340    0.544094   0.582057
# 16   0.739619  0.707841    0.540298   0.575181
# 17   0.742062  0.679914    0.527074   0.608628
# 18   0.745970  0.729323    0.531595   0.551295
# ...

# %%
# plot test acc
plt.plot(df_res_trans['test_acc'], label ='Resnet50-Transfer' )
plt.plot(df_res['test_acc'], label = 'Resnet50' )
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
# Out:
# c:\Users\mailt\Anaconda3\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mailt\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#
# TypeError: cannot convert the series to <class 'float'>
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...
